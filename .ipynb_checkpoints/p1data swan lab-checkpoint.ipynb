# %%
import pandas as pd
import matplotlib.pyplot as plt
import glob
import seaborn as sns
import numpy as np
import statsmodels as sm
from statsmodels.stats.anova import AnovaRM
import pingouin as pg

# %%
path = "csv_files/"
all_files = glob.glob(path + "*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)
    
block = []
i=0    
while i < 1000:
    block.append(i)
    i+=20
    

n=1
plt.figure(figsize = (20,30))
for df in li:
    fb = df[(df['block'] == 'fixed-blank') & (df['rt'] >= 0) & (df['correct'] == True)]
    ff = df[(df['block'] == 'fixed-filled') & (df['rt'] >= 0) & (df['correct'] == True)]
    v = df[(df['block'] == 'varied') & (df['rt'] >= 0) & (df['correct'] == True)]
    
    plt.subplot(6,3,n)
    plt.hist(fb.rt, bins=block, alpha=0.5, edgecolor="black", color="yellow", label="fixed-blank")
    plt.hist(ff.rt, bins=block, alpha=0.5, edgecolor="black", color="blue", label="fixed-filled")
    plt.hist(v.rt, bins=block, alpha=0.5, edgecolor="black", color="orange", label="varied")
    plt.legend(loc='upper right')
    plt.title("FP_P1_" + str(n))
    plt.xlabel("RT in ms")
    plt.ylabel("Number of Trials")
    n+=1
plt.show()

# %%
# clear out lists while troubleshooting
bpmns = []
fig, ax=plt.subplots()
plt.xlabel("Block Type")
plt.ylabel("Mean RT in ms")
for df in li:
    dfmns = []
    fb = df[(df['block'] == 'fixed-blank') & (df['rt'] >= 0) & (df['correct'] == True)]
    dfmns.append(fb.rt.mean())
    ff = df[(df['block'] == 'fixed-filled') & (df['rt'] >= 0) & (df['correct'] == True)]
    dfmns.append(ff.rt.mean())
    v = df[(df['block'] == 'varied') & (df['rt'] >= 0) & (df['correct'] == True)]
    dfmns.append(v.rt.mean())
    bpmns.append(dfmns)
    lst = [fb.rt.mean(), ff.rt.mean(), v.rt.mean()]
    lts = ['fixed-blank', 'fixed-filled', 'varied']
    ax.scatter(lts, lst, color='black')
    ax.plot(lts,lst, color="black")
    # [fbmn, ffmn, vmn]
FP_df = pd.DataFrame(np.array(bpmns), columns=['fixed-blank', 'fixed-filled', 'varied'])
FP_df.boxplot(positions=range(len(FP_df.columns)))
# Out:
# <AxesSubplot:xlabel='Block Type', ylabel='Mean RT in ms'>

# %%
i=0
anov = []
for df in li:
    fb = df[(df['block'] == 'fixed-blank') & (df['rt'] >= 0) & (df['correct'] == True)]
    anov.append([i, 1, fb.rt.mean()])
    ff = df[(df['block'] == 'fixed-filled') & (df['rt'] >= 0) & (df['correct'] == True)]
    anov.append([i, 2, ff.rt.mean()])
    v = df[(df['block'] == 'varied') & (df['rt'] >= 0) & (df['correct'] == True)]
    anov.append([i, 3, v.rt.mean()])
    i+=1
ANOVA_df = pd.DataFrame(np.array(anov), columns=['SUB_ID', 'BLOCK_TYPE', 'MEAN_RT'])

# %%
anovRM = AnovaRM(ANOVA_df, depvar='MEAN_RT', subject='SUB_ID', within=['BLOCK_TYPE'])
print(anovRM.fit())
# Out:
#                  Anova
# ========================================
#            F Value Num DF  Den DF Pr > F
# ----------------------------------------
# BLOCK_TYPE  5.1765 2.0000 20.0000 0.0154
# ========================================

# %%
bppct = []
fig, ax=plt.subplots()
plt.xlabel("Block Type")
plt.ylabel("Percent Correct Trials")
for df in li:
    dfpct = []
    fbc = df[(df['block'] == 'fixed-blank') & (df['rt'] >= 0) & (df['correct'] == True)]
    fbf = df[(df['block'] == 'fixed-blank') & (df['rt'] >= 0) & (df['correct'] == False)]
    sm = fbc.rt.count()+fbf.rt.count()
    fbpct = fbc.rt.count()/sm*100
    dfpct.append(fbpct)
    ffc = df[(df['block'] == 'fixed-filled') & (df['rt'] >= 0) & (df['correct'] == True)]
    fff = df[(df['block'] == 'fixed-filled') & (df['rt'] >= 0) & (df['correct'] == False)]
    sm = ffc.rt.count()+fff.rt.count()
    ffpct = ffc.rt.count()/sm*100
    dfpct.append(ffpct)
    vc = df[(df['block'] == 'varied') & (df['rt'] >= 0) & (df['correct'] == True)]
    vf = df[(df['block'] == 'varied') & (df['rt'] >= 0) & (df['correct'] == False)]
    sm = vc.rt.count()+vf.rt.count()
    vpct = vc.rt.count()/sm*100
    dfpct.append(vpct)
    bppct.append(dfpct)
    lst = [fbpct, ffpct, vpct]
    lts = ['fixed-blank', 'fixed-filled', 'varied']
    ax.scatter(lts, lst, color='black')
    ax.plot(lts,lst, color="black")
    # [fbmn, ffmn, vmn]
FP_df = pd.DataFrame(np.array(bppct), columns=['fixed-blank', 'fixed-filled', 'varied'])
FP_df.boxplot(positions=range(len(FP_df.columns)))
# Out:
# <AxesSubplot:xlabel='Block Type', ylabel='Percent Correct Trials'>

# %%
# clear out lists while troubleshooting
bpmns = []
fig, ax=plt.subplots()
ax.set_xlabel("Varied Block Time")
ax.set_ylabel("Mean RT in ms")
for df in li:
    dfmns = []
    two = df[(df['block'] == 'varied') & (df['rt'] >= 0) & (df['correct'] == True) & (df['fixation_duration'] == 200)]
    dfmns.append(two.rt.mean())
    four = df[(df['block'] == 'varied') & (df['rt'] >= 0) & (df['correct'] == True) & (df['fixation_duration'] == 400)]
    dfmns.append(four.rt.mean())
    six = df[(df['block'] == 'varied') & (df['rt'] >= 0) & (df['correct'] == True) & (df['fixation_duration'] == 600)]
    dfmns.append(six.rt.mean())
    eight = df[(df['block'] == 'varied') & (df['rt'] >= 0) & (df['correct'] == True) & (df['fixation_duration'] == 800)]
    dfmns.append(eight.rt.mean())
    ten = df[(df['block'] == 'varied') & (df['rt'] >= 0) & (df['correct'] == True) & (df['fixation_duration'] == 1000)]
    dfmns.append(ten.rt.mean())
    bpmns.append(dfmns)
    lst = [two.rt.mean(), four.rt.mean(), six.rt.mean(), eight.rt.mean(), ten.rt.mean()]
    lts = ['200', '400', '600', '800', '1000']
    ax.scatter(lts, lst, color='black')
    ax.plot(lts,lst, color="black")
    # [fbmn, ffmn, vmn]
FP_df = pd.DataFrame(np.array(bpmns), columns=['200', '400', '600', '800', '1000'])
FP_df.boxplot(positions=range(len(FP_df.columns)))
# Out:
# <AxesSubplot:xlabel='Varied Block Time', ylabel='Mean RT in ms'>

# %%
#Should maybe use a regression here because fixation duration is a continuous variable? Is it a linear relationship?
i=0
anov = []
for df in li:
    two = df[(df['block'] == 'varied') & (df['rt'] >= 0) & (df['correct'] == True) & (df['fixation_duration'] == 200)]
    anov.append([i, 200, two.rt.mean()])
    four = df[(df['block'] == 'varied') & (df['rt'] >= 0) & (df['correct'] == True) & (df['fixation_duration'] == 400)]
    anov.append([i, 400, four.rt.mean()])
    six = df[(df['block'] == 'varied') & (df['rt'] >= 0) & (df['correct'] == True) & (df['fixation_duration'] == 600)]
    anov.append([i, 600, six.rt.mean()])
    eight = df[(df['block'] == 'varied') & (df['rt'] >= 0) & (df['correct'] == True) & (df['fixation_duration'] == 800)]
    anov.append([i, 800, eight.rt.mean()])
    ten = df[(df['block'] == 'varied') & (df['rt'] >= 0) & (df['correct'] == True) & (df['fixation_duration'] == 1000)]
    anov.append([i, 1000, ten.rt.mean()])
    i+=1
ANOVA2_df = pd.DataFrame(np.array(anov), columns=['SUB_ID', 'fixation_duration', 'MEAN_RT'])

# %%
#Anova using each fixation duration 200, 400, 600, 800, and 1000 as a seperate condition 
anovRM = AnovaRM(ANOVA2_df, depvar='MEAN_RT', subject='SUB_ID', within=['fixation_duration'])
print(anovRM.fit())
# Out:
#                      Anova
# ===============================================
#                   F Value Num DF  Den DF Pr > F
# -----------------------------------------------
# fixation_duration  2.5745 4.0000 40.0000 0.0522
# ===============================================

# %%
bplen=[]
for df in li:
    dfmns = []
    two = df[(df['block'] == 'varied') & (df['rt'] >= 0) & (df['correct'] == True) & (df['fixation_duration'] == 200)]
    dfmns.append(len(two.rt))
    four = df[(df['block'] == 'varied') & (df['rt'] >= 0) & (df['correct'] == True) & (df['fixation_duration'] == 400)]
    dfmns.append(len(four.rt))
    six = df[(df['block'] == 'varied') & (df['rt'] >= 0) & (df['correct'] == True) & (df['fixation_duration'] == 600)]
    dfmns.append(len(six.rt))
    eight = df[(df['block'] == 'varied') & (df['rt'] >= 0) & (df['correct'] == True) & (df['fixation_duration'] == 800)]
    dfmns.append(len(eight.rt))
    ten = df[(df['block'] == 'varied') & (df['rt'] >= 0) & (df['correct'] == True) & (df['fixation_duration'] == 1000)]
    dfmns.append(len(ten.rt))
    bplen.append(dfmns)
FP_df2 = pd.DataFrame(np.array(bplen), columns=['200', '400', '600', '800', '1000'])

# %%
FP_df2
# Out:
#     200  400  600  800  1000
# 0    17   13   26   22    18
# 1    16   25   15   27    15
# 2    21   22   19   19    15
# 3    18   19   14   27    20
# 4    20   17   16   24    17
# 5    18   16   16   24    22
# 6    20   13   14   18    12
# 7    18   18   17   24    18
# 8    22   18   18   24    17
# 9    18   21   12   21    22
# 10   13   23   30   17    17
